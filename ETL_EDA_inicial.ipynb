# %%
import pandas as pd
import ast

# %% [markdown]
# <h1>Steam_games<h1\>

# %% [markdown]
# Se carga el dataset disponible y se realiza una primera visualizacion

# %%
#Se carga el archivo json
df_steam_games=pd.read_json('raw_data/output_steam_games.json', lines=True)
df_steam_games
# Out:
#               publisher                                 genres  \
# 0                  None                                   None
# 1                  None                                   None
# 2                  None                                   None
# 3                  None                                   None
# 4                  None                                   None
# ...                 ...                                    ...
# 120440  Ghost_RUS Games  [Casual, Indie, Simulation, Strategy]
# 120441           Sacada              [Casual, Indie, Strategy]
# 120442     Laush Studio            [Indie, Racing, Simulation]
# 120443         SIXNAILS                        [Casual, Indie]
# 120444             None                                   None
#
#                         app_name                     title  \
# 0                           None                      None
# 1                           None                      None
# ...

# %% [markdown]
# Se observa una gran cantidad de registros vacios. Se eliminan esos registros y se guarda el dataset en formato .csv

# %%
#Se eliminan las filas que tienen solo valores nulos
df_steam_games.dropna(how='all', inplace=True)
#Se guarda el dataset sin los registros nulos
df_steam_games.to_csv('processed_data/steam_games.csv',index=False)

# %%
#Se exporta una pequeña porcion del dataset en formato .xlsx para utilizar en un posterior EDA
head_games=df_steam_games.head()
head_games.to_excel('head_games.xlsx')

# %% [markdown]
# <h1>user_items<h1\>

# %% [markdown]
# Se carga el dataset disponible y se realiza una primera visualizacion

# %%
#Se carga el archivo json
filas = list()
with open("raw_data/australian_users_items.json", "r", encoding="Latin-1") as archivo:
    for linea in archivo.readlines():
        filas.append(ast.literal_eval(linea))

df_items = pd.DataFrame(filas)
df_items
# Out:
#                        user_id  items_count           steam_id  \
# 0            76561197970982479          277  76561197970982479
# 1                      js41637          888  76561198035864385
# 2                    evcentric          137  76561198007712555
# 3                   Riot-Punch          328  76561197963445855
# 4                        doctr          541  76561198002099482
# ...                        ...          ...                ...
# 88305        76561198323066619           22  76561198323066619
# 88306        76561198326700687          177  76561198326700687
# 88307  XxLaughingJackClown77xX            0  76561198328759259
# 88308        76561198329548331            7  76561198329548331
# 88309        edward_tremethick            0  76561198331598578
#
#                                                 user_url  \
# 0      http://steamcommunity.com/profiles/76561197970...
# 1                   http://steamcommunity.com/id/js41637
# ...

# %% [markdown]
# Se observa que dentro de la columna items hay diccionarios con informacion relevante. decidimos descomprimir esa informacion para tenerla disponible en nuevas columnas

# %%
#Se extraen los datos de la columna items en filas
df_items = df_items.explode("items").reset_index()
df_items = df_items.drop(columns="index")

#Se normalizan esos datos en columnas
df_items = pd.concat([df_items, pd.json_normalize(df_items['items'])], axis=1)
df_items.head()
# Out:
#              user_id  items_count           steam_id  \
# 0  76561197970982479          277  76561197970982479
# 1  76561197970982479          277  76561197970982479
# 2  76561197970982479          277  76561197970982479
# 3  76561197970982479          277  76561197970982479
# 4  76561197970982479          277  76561197970982479
#
#                                             user_url  \
# 0  http://steamcommunity.com/profiles/76561197970...
# 1  http://steamcommunity.com/profiles/76561197970...
# 2  http://steamcommunity.com/profiles/76561197970...
# 3  http://steamcommunity.com/profiles/76561197970...
# 4  http://steamcommunity.com/profiles/76561197970...
#
#                                                items item_id  \
# 0  {'item_id': '10', 'item_name': 'Counter-Strike...      10
# 1  {'item_id': '20', 'item_name': 'Team Fortress ...      20
# 2  {'item_id': '30', 'item_name': 'Day of Defeat'...      30
# 3  {'item_id': '40', 'item_name': 'Deathmatch Cla...      40
# ...

# %%
#Se elimina la columna items
df_items.drop(columns='items', inplace=True)

# %%
#Se exporta una pequeña porcion del dataset en formato .xlsx para utilizar en un posterior EDA
head_items=df_items.head()
head_items.to_excel('head_items.xlsx')

# %%
#Se guarda el dataset en formato parquet
df_items.to_parquet('processed_data/items_inicial.parquet')

# %% [markdown]
# <h1>user_Reviews<h1\>

# %% [markdown]
# Se carga el dataset disponible y se realiza una primera visualizacion

# %%
#Se carga el archivo json
filas = list()
with open("raw_data/australian_user_reviews.json", "r",encoding="Latin-1") as archivo:
    for linea in archivo.readlines():
        filas.append(ast.literal_eval(linea))

df_reviews = pd.DataFrame(filas)
df_reviews
# Out:
#                  user_id                                           user_url  \
# 0      76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1                js41637               http://steamcommunity.com/id/js41637
# 2              evcentric             http://steamcommunity.com/id/evcentric
# 3                  doctr                 http://steamcommunity.com/id/doctr
# 4              maplemage             http://steamcommunity.com/id/maplemage
# ...                  ...                                                ...
# 25794  76561198306599751  http://steamcommunity.com/profiles/76561198306...
# 25795           Ghoustik              http://steamcommunity.com/id/Ghoustik
# 25796  76561198310819422  http://steamcommunity.com/profiles/76561198310...
# 25797  76561198312638244  http://steamcommunity.com/profiles/76561198312...
# 25798        LydiaMorley           http://steamcommunity.com/id/LydiaMorley
#
#                                                  reviews
# ...

# %% [markdown]
# Se observa que dentro de la columna items hay diccionarios con informacion relevante. decidimos descomprimir esa informacion para tenerla disponible en nuevas columnas

# %%
#Se extraen los datos de la columna items en filas
df_reviews = df_reviews.explode("reviews").reset_index()
df_reviews = df_reviews.drop(columns="index")

#Se normalizan esos datos en columnas
df_reviews = pd.concat([df_reviews, pd.json_normalize(df_reviews['reviews'])], axis=1)
df_reviews.head()
# Out:
#              user_id                                           user_url  \
# 0  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 1  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 2  76561197970982479  http://steamcommunity.com/profiles/76561197970...
# 3            js41637               http://steamcommunity.com/id/js41637
# 4            js41637               http://steamcommunity.com/id/js41637
#
#                                              reviews funny  \
# 0  {'funny': '', 'posted': 'Posted November 5, 20...
# 1  {'funny': '', 'posted': 'Posted July 15, 2011....
# 2  {'funny': '', 'posted': 'Posted April 21, 2011...
# 3  {'funny': '', 'posted': 'Posted June 24, 2014....
# 4  {'funny': '', 'posted': 'Posted September 8, 2...
#
#                       posted last_edited item_id  \
# 0   Posted November 5, 2011.                1250
# 1      Posted July 15, 2011.               22200
# 2     Posted April 21, 2011.               43110
# ...

# %%
#Se elimina la columna reviews
df_reviews.drop(columns='reviews',inplace=True)

# %%
#Se exporta una pequeña porcion del dataset en formato .xlsx para utilizar en un posterior EDA
head_reviews=df_reviews.head()
head_reviews.to_excel('head_reviews.xlsx')

# %%
#Se guarda el dataset en formato parquet
df_reviews.to_parquet('processed_data/reviews_inicial.parquet')

# %% [markdown]
# En la siguiente planilla utilizamos la estructira de cada tabla y las funciones a realizar para cada endpoint, para asi poder identificar cuales campos necesitaremos a lo largo de nuestro proyecto y cuales podemos eliminar: https://docs.google.com/spreadsheets/d/1VMXfzuVTL1q-LO6SD5CEii_C-iBGNta8IEZz_Y_y4qE/edit?usp=sharing

# %% [markdown]
# Teniendo ya una primera visualizacion de nuestros datasets, comprendiendo cada campo, sus tipos de datos y la relacion entre los mismos, procedemos a confeccionar un ETL y EDA mas profundo a cada dataset en particular, en los notebooks ETL_EDA_games, ETL_EDA_items y ETL_EDA_reviews.
